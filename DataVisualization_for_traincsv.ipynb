# %%
#Imports
import os
import pandas as pd
import numpy as mp
import seaborn as sb
import matplotlib
import pydicom as dcm
import glob

# %%
#Prints file name to make sure file/path location is correct
print("file and respective path: ")
i = 0
for dirname, _, filenames in os.walk('C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/'):
    for filename in filenames:
        if i < 10:
            print(os.path.join(dirname, filename))
            i += 1
# Out:
# file and respective path:
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/sample_submission.csv
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test.csv
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/train.csv
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\1.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\10.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\11.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\12.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\13.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\14.dcm
# C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/test\ID00419637202311204720264\15.dcm

# %%
# patient info data framing
df = pd.read_csv('C:/Users/Poras/Desktop/osic-pulmonary-fibrosis-progression/train.csv')
df.head(10)
print(df.head(10))
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker
# 5  ID00007637202177411956430     17  2101  52.868646   79  Male     Ex-smoker
# 6  ID00007637202177411956430     29  2000  50.327126   79  Male     Ex-smoker
# 7  ID00007637202177411956430     41  2064  51.937594   79  Male     Ex-smoker
# 8  ID00007637202177411956430     57  2057  51.761449   79  Male     Ex-smoker
# 9  ID00009637202177434476278      8  3660  85.282878   69  Male     Ex-smoker

# %%
# info on columns and rows for data frame
# df.describe gives us statistical rundown of train.csv data
df.keys()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient        1549 non-null   object
#  1   Weeks          1549 non-null   int64
#  2   FVC            1549 non-null   int64
#  3   Percent        1549 non-null   float64
#  4   Age            1549 non-null   int64
#  5   Sex            1549 non-null   object
#  6   SmokingStatus  1549 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 84.8+ KB
#              Weeks          FVC      Percent          Age
# count  1549.000000  1549.000000  1549.000000  1549.000000
# mean     31.861846  2690.479019    77.672654    67.188509
# std      23.247550   832.770959    19.823261     7.057395
# min      -5.000000   827.000000    28.877577    49.000000
# 25%      12.000000  2109.000000    62.832700    63.000000
# 50%      28.000000  2641.000000    75.676937    68.000000
# ...

# %%
# total number of patients in train.csv (should be: 176)
df['Patient'].nunique()
# Out:
# 176

# %%
FVC = df['FVC']
Age = df['Age']
Percentage = df['Percent']
Sex = df['Sex']
Weeks = df['Weeks']
df2 = df[['Age', 'Weeks', 'FVC']]

# %%
# Age distribution of Train.csv
print(sb.countplot(y='Age', data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Age vs FCV spread of train.csv
print(sb.relplot(y='Age', x='FVC', data=df))

# %%
#
print(sb.relplot(y='Weeks', x='FVC', data=df))

# %%
#Sex count of train.csv
print(sb.countplot(y='Sex', data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
